# %%
#This notebook is written using google colab
import pandas as pd

# %%
file_path='/content/retail_analytics_20k.csv.xls'

# %%
df=pd.read_csv(file_path)
df
# Out:
#          order_id  order_date  year  month month_name quarter customer_id  \
# 0      ORD-000001  2025-10-16  2025     10    October      Q4  CUST-02941
# 1      ORD-000002  2025-09-10  2025      9  September      Q3  CUST-01402
# 2      ORD-000003  2024-09-07  2024      9  September      Q3  CUST-03272
# 3      ORD-000004  2024-08-12  2024      8     August      Q3  CUST-02158
# 4      ORD-000005  2024-07-01  2024      7       July      Q3  CUST-04418
# ...           ...         ...   ...    ...        ...     ...         ...
# 19995  ORD-019996  2025-09-09  2025      9  September      Q3  CUST-02548
# 19996  ORD-019997  2025-06-26  2025      6       June      Q2  CUST-00626
# 19997  ORD-019998  2025-01-11  2025      1    January      Q1  CUST-03102
# 19998  ORD-019999  2025-06-15  2025      6       June      Q2  CUST-03543
# 19999  ORD-020000  2024-06-17  2024      6       June      Q2  CUST-03783
#
#          customer_segment age_group  gender  ... unit_price_egp discount_pct  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   order_id                        20000 non-null  object
#  1   order_date                      20000 non-null  object
#  2   year                            20000 non-null  int64
#  3   month                           20000 non-null  int64
#  4   month_name                      20000 non-null  object
#  5   quarter                         20000 non-null  object
#  6   customer_id                     20000 non-null  object
#  7   customer_segment                20000 non-null  object
#  8   age_group                       20000 non-null  object
#  9   gender                          20000 non-null  object
#  10  country                         20000 non-null  object
#  11  region                          20000 non-null  object
# ...

# %%
df.isna()
df.isna().sum()
# Out:
# order_id                          0
# order_date                        0
# year                              0
# month                             0
# month_name                        0
# quarter                           0
# customer_id                       0
# customer_segment                  0
# age_group                         0
# gender                            0
# country                           0
# region                            0
# city                              0
# sales_channel                     0
# traffic_source                    0
# category                          0
# sub_category                      0
# product_name                      0
# payment_method                    0
# shipping_method                   0
# campaign                          0
# quantity                          0
# unit_price_egp                    0
# discount_pct                      0
# revenue_egp                       0
# cost_egp                          0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cleaned=df
df_cleaned['order_date']=pd.to_datetime(df_cleaned['order_date'])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   order_id                        20000 non-null  object
#  1   order_date                      20000 non-null  datetime64[ns]
#  2   year                            20000 non-null  int64
#  3   month                           20000 non-null  int64
#  4   month_name                      20000 non-null  object
#  5   quarter                         20000 non-null  object
#  6   customer_id                     20000 non-null  object
#  7   customer_segment                20000 non-null  object
#  8   age_group                       20000 non-null  object
#  9   gender                          20000 non-null  object
#  10  country                         20000 non-null  object
#  11  region                          20000 non-null  object
# ...

# %%
egp = df_cleaned.groupby(['revenue_egp','cost_egp','profit_egp'])['profit_margin'].mean().reset_index()
egp
# Out:
#        revenue_egp   cost_egp  profit_egp  profit_margin
# 0            41.33      22.02       19.31         0.4672
# 1            41.35      18.61       22.74         0.5499
# 2            42.68      22.94       19.74         0.4625
# 3            44.03      22.96       21.07         0.4785
# 4            46.89      25.79       21.10         0.4500
# ...            ...        ...         ...            ...
# 19995    224647.78  174082.98    50564.80         0.2251
# 19996    227489.33  172439.57    55049.76         0.2420
# 19997    235205.90  176433.00    58772.90         0.2499
# 19998    236022.13  197308.35    38713.78         0.1640
# 19999    264466.61  218784.56    45682.05         0.1727
#
# [20000 rows x 4 columns]

# %%
(egp < 0).any()
# Out:
# revenue_egp      False
# cost_egp         False
# profit_egp       False
# profit_margin    False
# dtype: bool

# %%
# Save DataFrame to CSV
df_cleaned.to_csv('sales_data.csv', index=False)
